# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso,LogisticRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import warnings

# %%
df=pd.read_csv(r"D:\python\Machine Learning\ML projects\2 breast cancer predicter\Artifacts\raw_data.csv")
df.head(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#                  id    diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  1.138000e+03  1138.000000  1138.000000   1138.000000     1138.000000
# mean   3.037183e+07     0.372583    14.127292     19.289649       91.969033
# std    1.249656e+08     0.483705     3.522499      4.299144       24.288293
# min    8.670000e+03     0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05     0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05     0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06     1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08     1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count  1138.000000      1138.000000       1138.000000     1138.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.759340         0.014058          0.052790        0.079685
# min     143.500000         0.052630          0.019380        0.000000
# 25%     420.300000         0.086370          0.064920        0.029560
# 50%     551.100000         0.095870          0.092630        0.061540
# 75%     782.700000         0.105300          0.130400        0.130700
# max    2501.000000         0.163400          0.345400        0.426800
#
#        concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count          1138.000000  ...   1138.000000    1138.000000      1138.000000
# mean              0.048919  ...     16.269190      25.677223       107.261213
# std               0.038786  ...      4.831116       6.143554        33.587762
# min               0.000000  ...      7.930000      12.020000        50.410000
# 25%               0.020310  ...     13.010000      21.080000        84.110000
# 50%               0.033500  ...     14.970000      25.410000        97.660000
# 75%               0.074000  ...     18.790000      29.720000       125.400000
# max               0.201200  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count  1138.000000       1138.000000        1138.000000      1138.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.106561          0.022822           0.157267         0.208533
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count           1138.000000     1138.000000              1138.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065703        0.061840                 0.018053
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 32 columns]

# %%
# Remove the header row that was mistakenly inserted as data
df = df[df["id"] != "id"]

# Convert id to int after filtering
df["id"] = df["id"].astype("int64")
df["diagnosis"] = df["diagnosis"].astype("int64")
df[df.columns[2:]] = df[df.columns[2:]].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1138 non-null   int64
#  1   diagnosis                1138 non-null   int64
#  2   radius_mean              1138 non-null   float64
#  3   texture_mean             1138 non-null   float64
#  4   perimeter_mean           1138 non-null   float64
#  5   area_mean                1138 non-null   float64
#  6   smoothness_mean          1138 non-null   float64
#  7   compactness_mean         1138 non-null   float64
#  8   concavity_mean           1138 non-null   float64
#  9   concave points_mean      1138 non-null   float64
#  10  symmetry_mean            1138 non-null   float64
#  11  fractal_dimension_mean   1138 non-null   float64
#  12  radius_se                1138 non-null   float64
#  13  texture_se               1138 non-null   float64
#  14  perimeter_se             1138 non-null   float64
#  15  area_se                  1138 non-null   float64
#  16  smoothness_se            1138 non-null   float64
#  17  compactness_se           1138 non-null   float64
#  18  concavity_se             1138 non-null   float64
#  19  concave points_se        1138 non-null   float64
#  20  symmetry_se              1138 non-null   float64
#  21  fractal_dimension_se     1138 non-null   float64
#  22  radius_worst             1138 non-null   float64
#  23  texture_worst            1138 non-null   float64
#  24  perimeter_worst          1138 non-null   float64
#  25  area_worst               1138 non-null   float64
#  26  smoothness_worst         1138 non-null   float64
#  27  compactness_worst        1138 non-null   float64
#  28  concavity_worst          1138 non-null   float64
#  29  concave points_worst     1138 non-null   float64
#  30  symmetry_worst           1138 non-null   float64
#  31  fractal_dimension_worst  1138 non-null   float64
# dtypes: float64(30), int64(2)
# memory usage: 284.6 KB

# %%
X = df.drop('diagnosis',axis=1)
y = df["diagnosis"]
X
# Out:
#             id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0       842302        17.99         10.38          122.80     1001.0
# 1       842517        20.57         17.77          132.90     1326.0
# 2     84300903        19.69         21.25          130.00     1203.0
# 3     84348301        11.42         20.38           77.58      386.1
# 4     84358402        20.29         14.34          135.10     1297.0
# ...        ...          ...           ...             ...        ...
# 1133    926424        21.56         22.39          142.00     1479.0
# 1134    926682        20.13         28.25          131.20     1261.0
# 1135    926954        16.60         28.08          108.30      858.1
# 1136    927241        20.60         29.33          140.10     1265.0
# 1137     92751         7.76         24.54           47.92      181.0
#
#       smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0             0.11840           0.27760         0.30010              0.14710
# 1             0.08474           0.07864         0.08690              0.07017
# 2             0.10960           0.15990         0.19740              0.12790
# 3             0.14250           0.28390         0.24140              0.10520
# 4             0.10030           0.13280         0.19800              0.10430
# ...               ...               ...             ...                  ...
# 1133          0.11100           0.11590         0.24390              0.13890
# 1134          0.09780           0.10340         0.14400              0.09791
# 1135          0.08455           0.10230         0.09251              0.05302
# 1136          0.11780           0.27700         0.35140              0.15200
# 1137          0.05263           0.04362         0.00000              0.00000
#
#       symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0            0.2419  ...        25.380          17.33           184.60
# 1            0.1812  ...        24.990          23.41           158.80
# 2            0.2069  ...        23.570          25.53           152.50
# 3            0.2597  ...        14.910          26.50            98.87
# 4            0.1809  ...        22.540          16.67           152.20
# ...             ...  ...           ...            ...              ...
# 1133         0.1726  ...        25.450          26.40           166.10
# 1134         0.1752  ...        23.690          38.25           155.00
# 1135         0.1590  ...        18.980          34.12           126.70
# 1136         0.2397  ...        25.740          39.42           184.60
# 1137         0.1587  ...         9.456          30.37            59.16
#
#       area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0         2019.0           0.16220            0.66560           0.7119
# 1         1956.0           0.12380            0.18660           0.2416
# 2         1709.0           0.14440            0.42450           0.4504
# 3          567.7           0.20980            0.86630           0.6869
# 4         1575.0           0.13740            0.20500           0.4000
# ...          ...               ...                ...              ...
# 1133      2027.0           0.14100            0.21130           0.4107
# 1134      1731.0           0.11660            0.19220           0.3215
# 1135      1124.0           0.11390            0.30940           0.3403
# 1136      1821.0           0.16500            0.86810           0.9387
# 1137       268.6           0.08996            0.06444           0.0000
#
#       concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                   0.2654          0.4601                  0.11890
# 1                   0.1860          0.2750                  0.08902
# 2                   0.2430          0.3613                  0.08758
# 3                   0.2575          0.6638                  0.17300
# 4                   0.1625          0.2364                  0.07678
# ...                    ...             ...                      ...
# 1133                0.2216          0.2060                  0.07115
# 1134                0.1628          0.2572                  0.06637
# 1135                0.1418          0.2218                  0.07820
# 1136                0.2650          0.4087                  0.12400
# 1137                0.0000          0.2871                  0.07039
#
# [1138 rows x 31 columns]

# %%
null_column = X.columns[X.isnull().any()]
null_column
# Out:
# Index([], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

pipeline = Pipeline([
    ("imputer",SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.95))
])

X_pre = pipeline.fit_transform(X)

# %%
X_pre.shape
# Out:
# (1138, 11)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_pre,y,test_size=0.2,random_state=42)
X_train.shape,X_test.shape
# Out:
# ((910, 11), (228, 11))

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor(),
    "LogisticRegression":LogisticRegression()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.2585
# - Mean Absolute Error: 0.2042
# - R2 Score: 0.7171
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.2535
# - Mean Absolute Error: 0.2041
# - R2 Score: 0.7108
# ===================================
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.4044
# - Mean Absolute Error: 0.3873
# - R2 Score: 0.3076
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.3980
# - Mean Absolute Error: 0.3808
# - R2 Score: 0.2872
# ===================================
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.2585
# - Mean Absolute Error: 0.2042
# - R2 Score: 0.7171
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.2535
# - Mean Absolute Error: 0.2041
# - R2 Score: 0.7108
# ===================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.1107
# - Mean Absolute Error: 0.0279
# - R2 Score: 0.9481
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1573
# - Mean Absolute Error: 0.0430
# - R2 Score: 0.8887
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.0000
# - Mean Absolute Error: 0.0000
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0937
# - Mean Absolute Error: 0.0088
# - R2 Score: 0.9605
# ===================================
#
#
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.0400
# - Mean Absolute Error: 0.0142
# - R2 Score: 0.9932
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0789
# - Mean Absolute Error: 0.0299
# - R2 Score: 0.9720
# ===================================
#
#
# XGBRegressor
# Model performance for Training set
# - Root Mean Squared Error: 0.0007
# - Mean Absolute Error: 0.0004
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0776
# - Mean Absolute Error: 0.0089
# - R2 Score: 0.9729
# ===================================
#
#
# CatBoosting Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.0131
# - Mean Absolute Error: 0.0084
# - R2 Score: 0.9993
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0540
# - Mean Absolute Error: 0.0234
# - R2 Score: 0.9869
# ===================================
#
#
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.1222
# - Mean Absolute Error: 0.0846
# - R2 Score: 0.9367
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1433
# - Mean Absolute Error: 0.0983
# - R2 Score: 0.9075
# ===================================
#
#
# LogisticRegression
# Model performance for Training set
# - Root Mean Squared Error: 0.1195
# - Mean Absolute Error: 0.0143
# - R2 Score: 0.9395
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1147
# - Mean Absolute Error: 0.0132
# - R2 Score: 0.9408
# ===================================

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 7    CatBoosting Regressor  0.986867
# 6             XGBRegressor  0.972889
# 5  Random Forest Regressor  0.971995
# 4            Decision Tree  0.960526
# 9       LogisticRegression  0.940789
# 8       AdaBoost Regressor  0.907529
# 3    K-Neighbors Regressor  0.888684
# 2                    Ridge  0.710798
# 0        Linear Regression  0.710788
# 1                    Lasso  0.287180

# %%
df1 = pd.read_csv(os.path.join("Artifacts","raw_data.csv"))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1138 non-null   int64
#  1   diagnosis                1138 non-null   int64
#  2   radius_mean              1138 non-null   float64
#  3   texture_mean             1138 non-null   float64
#  4   perimeter_mean           1138 non-null   float64
#  5   area_mean                1138 non-null   float64
#  6   smoothness_mean          1138 non-null   float64
#  7   compactness_mean         1138 non-null   float64
#  8   concavity_mean           1138 non-null   float64
#  9   concave points_mean      1138 non-null   float64
#  10  symmetry_mean            1138 non-null   float64
#  11  fractal_dimension_mean   1138 non-null   float64
#  12  radius_se                1138 non-null   float64
#  13  texture_se               1138 non-null   float64
#  14  perimeter_se             1138 non-null   float64
#  15  area_se                  1138 non-null   float64
#  16  smoothness_se            1138 non-null   float64
#  17  compactness_se           1138 non-null   float64
#  18  concavity_se             1138 non-null   float64
#  19  concave points_se        1138 non-null   float64
#  20  symmetry_se              1138 non-null   float64
#  21  fractal_dimension_se     1138 non-null   float64
#  22  radius_worst             1138 non-null   float64
#  23  texture_worst            1138 non-null   float64
#  24  perimeter_worst          1138 non-null   float64
#  25  area_worst               1138 non-null   float64
#  26  smoothness_worst         1138 non-null   float64
#  27  compactness_worst        1138 non-null   float64
#  28  concavity_worst          1138 non-null   float64
#  29  concave points_worst     1138 non-null   float64
#  30  symmetry_worst           1138 non-null   float64
#  31  fractal_dimension_worst  1138 non-null   float64
# dtypes: float64(30), int64(2)
# memory usage: 284.6 KB
